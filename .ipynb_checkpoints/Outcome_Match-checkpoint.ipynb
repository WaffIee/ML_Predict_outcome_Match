# %% [markdown]
# # Predicting the outcome of a NBA match

# %% [markdown]
# analyze various factors and make predictions based on historical data. & predicting the outcome of a NBA match using deferent classification models and comapre the performance metrics between them

# %%
# instalations
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# Imports: 

import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import matplotlib.pyplot as plt

import seaborn as sns


import numpy as np

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Data Importing and Cleaning:

# %% [markdown]
# ### 1.1 Importing & Exploring

# %%
import pandas as pd

#Games dataset
dataset_path = "/Users/wafaabajjouk/ML_PROJECT/games.csv"
df = pd.read_csv(dataset_path)

df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID
# 0    2022-12-22  22200477            Final    1610612740       1610612759  \
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0  \
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away
# 0      46.0    1610612759     117.0        0.478        0.815         0.321  \
# 1      40.0    1610612764     112.0        0.561        0.765         0.333
# 2      37.0    1610612749     106.0        0.470        0.682         0.433
# 3      49.0    1610612765      93.0        0.392        0.735         0.261
# 4      47.0    1610612741     110.0        0.500        0.773         0.292
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      23.0      44.0               1
# 1      20.0      37.0               1
# 2      20.0      46.0               1
# 3      15.0      46.0               1
# 4      20.0      47.0               0
#
# [5 rows x 21 columns]

# %%
# Teams Dataset
dataset_path = "/Users/wafaabajjouk/ML_PROJECT/teams.csv"
df = pd.read_csv(dataset_path)

df.head()
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME
# 0          0  1610612737      1949      2019          ATL      Hawks  \
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY
# 0         1949      Atlanta          State Farm Arena        18729.0  \
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# 0     Tony Ressler  Travis Schlenk   Lloyd Pierce      Erie Bayhawks
# 1    Wyc Grousbeck     Danny Ainge   Brad Stevens    Maine Red Claws
# 2       Tom Benson  Trajan Langdon   Alvin Gentry       No Affiliate
# 3  Jerry Reinsdorf      Gar Forman     Jim Boylen   Windy City Bulls
# 4       Mark Cuban   Donnie Nelson  Rick Carlisle      Texas Legends

# %% [markdown]
# ### 1.2 Cleaning
#
# #### Replacing the teams ID with their respective team names

# %% [markdown]
# The ID culumns ('HOME_TEAM_ID' and 'VISITOR_TEAM_ID') are in games.csv .
#
# The Teams names culumn ('NICKNAME') is in team.csv
#
# We will replace the team IDs in the HOME_TEAM_ID and VISITOR_TEAM_ID columns of the games.csv dataset with their respective team names from the team.csv dataset
#
# The changes will be saved in seperated new excel file
#
# The name culums are visitor_team and home_team

# %%
games_df = pd.read_csv('games.csv')
teams_df = pd.read_csv('teams.csv')

team_id_to_name = dict(zip(teams_df['TEAM_ID'], teams_df['NICKNAME']))

games_df['HOME_TEAM_ID'].replace(team_id_to_name, inplace=True)
games_df.rename(columns={'HOME_TEAM_ID': 'home_team'}, inplace=True)

games_df['VISITOR_TEAM_ID'].replace(team_id_to_name, inplace=True)
games_df.rename(columns={'VISITOR_TEAM_ID': 'visitor_team'}, inplace=True)

output_file = 'games_with_team_names.csv'
games_df.to_csv(output_file, index=False)
games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  home_team visitor_team  SEASON
# 0    2022-12-22  22200477            Final   Pelicans        Spurs    2022  \
# 1    2022-12-22  22200478            Final       Jazz      Wizards    2022
# 2    2022-12-21  22200466            Final  Cavaliers        Bucks    2022
# 3    2022-12-21  22200467            Final      76ers      Pistons    2022
# 4    2022-12-21  22200468            Final      Hawks        Bulls    2022
#
#    TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  REB_home
# 0    1610612740     126.0        0.484        0.926  ...      25.0      46.0  \
# 1    1610612762     120.0        0.488        0.952  ...      16.0      40.0
# 2    1610612739     114.0        0.482        0.786  ...      22.0      37.0
# 3    1610612755     113.0        0.441        0.909  ...      27.0      49.0
# 4    1610612737     108.0        0.429        1.000  ...      22.0      47.0
#
#    TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away
# 0    1610612759     117.0        0.478        0.815         0.321      23.0  \
# 1    1610612764     112.0        0.561        0.765         0.333      20.0
# 2    1610612749     106.0        0.470        0.682         0.433      20.0
# 3    1610612765      93.0        0.392        0.735         0.261      15.0
# 4    1610612741     110.0        0.500        0.773         0.292      20.0
#
#    REB_away  HOME_TEAM_WINS
# 0      44.0               1
# 1      37.0               1
# 2      46.0               1
# 3      46.0               1
# 4      47.0               0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Drop rows with NaN values

# %%
columns_to_check = ['TEAM_ID_home', 'TEAM_ID_away', 'PTS_home', 'PTS_away']
dataset_cleaned = games_df.dropna(subset=columns_to_check)
games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  home_team visitor_team  SEASON
# 0    2022-12-22  22200477            Final   Pelicans        Spurs    2022  \
# 1    2022-12-22  22200478            Final       Jazz      Wizards    2022
# 2    2022-12-21  22200466            Final  Cavaliers        Bucks    2022
# 3    2022-12-21  22200467            Final      76ers      Pistons    2022
# 4    2022-12-21  22200468            Final      Hawks        Bulls    2022
#
#    TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  REB_home
# 0    1610612740     126.0        0.484        0.926  ...      25.0      46.0  \
# 1    1610612762     120.0        0.488        0.952  ...      16.0      40.0
# 2    1610612739     114.0        0.482        0.786  ...      22.0      37.0
# 3    1610612755     113.0        0.441        0.909  ...      27.0      49.0
# 4    1610612737     108.0        0.429        1.000  ...      22.0      47.0
#
#    TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away
# 0    1610612759     117.0        0.478        0.815         0.321      23.0  \
# 1    1610612764     112.0        0.561        0.765         0.333      20.0
# 2    1610612749     106.0        0.470        0.682         0.433      20.0
# 3    1610612765      93.0        0.392        0.735         0.261      15.0
# 4    1610612741     110.0        0.500        0.773         0.292      20.0
#
#    REB_away  HOME_TEAM_WINS
# 0      44.0               1
# 1      37.0               1
# 2      46.0               1
# 3      46.0               1
# 4      47.0               0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### drop culumns

# %%
games_df = pd.read_csv('games_with_team_names.csv')
columns_to_drop = ['GAME_DATE_EST', 'SEASON',  'GAME_ID','GAME_STATUS_TEXT']
games_df = games_df.dropna(subset=columns_to_check)
games_df.to_csv('games_cleaned.csv', index=False)
games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  home_team visitor_team  SEASON
# 0    2022-12-22  22200477            Final   Pelicans        Spurs    2022  \
# 1    2022-12-22  22200478            Final       Jazz      Wizards    2022
# 2    2022-12-21  22200466            Final  Cavaliers        Bucks    2022
# 3    2022-12-21  22200467            Final      76ers      Pistons    2022
# 4    2022-12-21  22200468            Final      Hawks        Bulls    2022
#
#    TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  REB_home
# 0    1610612740     126.0        0.484        0.926  ...      25.0      46.0  \
# 1    1610612762     120.0        0.488        0.952  ...      16.0      40.0
# 2    1610612739     114.0        0.482        0.786  ...      22.0      37.0
# 3    1610612755     113.0        0.441        0.909  ...      27.0      49.0
# 4    1610612737     108.0        0.429        1.000  ...      22.0      47.0
#
#    TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away
# 0    1610612759     117.0        0.478        0.815         0.321      23.0  \
# 1    1610612764     112.0        0.561        0.765         0.333      20.0
# 2    1610612749     106.0        0.470        0.682         0.433      20.0
# 3    1610612765      93.0        0.392        0.735         0.261      15.0
# 4    1610612741     110.0        0.500        0.773         0.292      20.0
#
#    REB_away  HOME_TEAM_WINS
# 0      44.0               1
# 1      37.0               1
# 2      46.0               1
# 3      46.0               1
# 4      47.0               0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 2.Data Statistics

# %% [markdown]
# #### 2.1 Calculate the winning probabilities based on historical data:
#
# - calculating the probabilities of winning for each team as the home team and as the visitor team
# - Storing the new data in new dataframes

# %%
total_games = len(games_df)

home_team_wins = games_df['home_team'].value_counts()
home_team_win_percentage = (home_team_wins / total_games) * 100

visitor_team_wins = games_df['visitor_team'].value_counts()
visitor_team_win_percentage = (visitor_team_wins / total_games) * 100

team_win_percentage_df = pd.DataFrame({
    'Team': home_team_win_percentage.index,
    'Win Percentage as Home Team': home_team_win_percentage.values,
    'Win Percentage as Visitor Team': visitor_team_win_percentage.values
})

team_win_percentage_df.head()
# Out:
#         Team  Win Percentage as Home Team  Win Percentage as Visitor Team
# 0     Lakers                     3.619313                        3.525158
# 1       Heat                     3.600482                        3.517626
# 2    Celtics                     3.566586                        3.495029
# 3      Spurs                     3.528924                        3.442302
# 4  Cavaliers                     3.461133                        3.434770

# %%
total_games = len(games_df)

team_wins = pd.concat([games_df['home_team'], games_df['visitor_team']]).value_counts()
team_win_percentage = (team_wins / total_games) * 100

team_win_percentage_df = pd.DataFrame({
    'Team': team_win_percentage.index,
    'Win Percentage': team_win_percentage.values
})

team_win_percentage_df.head()
# Out:
#        Team  Win Percentage
# 0      Heat        7.125640
# 1   Celtics        7.084212
# 2     Spurs        7.023953
# 3    Lakers        6.892136
# 4  Warriors        6.839409

# %% [markdown]
#  - save the new data frams in the working csv file

# %%
games_df['Win_Pct_as_Home_Team'] = games_df['home_team'].map(home_team_win_prob)
games_df['Win_Pct_as_Visitor_Team'] = games_df['visitor_team'].map(visitor_team_win_prob)
games_df['Win_Pct'] = games_df['visitor_team'].map(visitor_team_win_prob)

games_df.to_csv('games_cleaned.csv', index=False)

games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  home_team visitor_team  SEASON
# 0    2022-12-22  22200477            Final   Pelicans        Spurs    2022  \
# 1    2022-12-22  22200478            Final       Jazz      Wizards    2022
# 2    2022-12-21  22200466            Final  Cavaliers        Bucks    2022
# 3    2022-12-21  22200467            Final      76ers      Pistons    2022
# 4    2022-12-21  22200468            Final      Hawks        Bulls    2022
#
#    TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  PTS_away
# 0    1610612740     126.0        0.484        0.926  ...     117.0  \
# 1    1610612762     120.0        0.488        0.952  ...     112.0
# 2    1610612739     114.0        0.482        0.786  ...     106.0
# 3    1610612755     113.0        0.441        0.909  ...      93.0
# 4    1610612737     108.0        0.429        1.000  ...     110.0
#
#    FG_PCT_away  FT_PCT_away  FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0        0.478        0.815         0.321      23.0      44.0               1  \
# 1        0.561        0.765         0.333      20.0      37.0               1
# 2        0.470        0.682         0.433      20.0      46.0               1
# 3        0.392        0.735         0.261      15.0      46.0               1
# 4        0.500        0.773         0.292      20.0      47.0               0
#
#    Win_Pct_as_Home_Team  Win_Pct_as_Visitor_Team   Win_Pct
# 0              3.197499                 3.495029  3.495029
# 1              3.276589                 3.359446  3.359446
# 2              3.461133                 3.351913  3.351913
# 3              3.295420                 3.329316  3.329316
# 4              3.318017                 3.269057  3.269057
#
# [5 rows x 24 columns]

# %%
import pandas as pd

def calculate_elo_rating(win_percentage):
    base_elo_rating = 1500  # Initial Elo rating for all teams
    k_factor = 32  # The k-factor determines the weight of the game in the Elo rating system
    
    # Calculate the Elo rating based on the win percentage
    elo_rating = base_elo_rating + k_factor * (win_percentage - 0.5)
    
    return elo_rating

def add_elo_ratings(dataset, team1_column, team2_column):
    # Convert win percentage columns to numeric type
    dataset['Win_Pct_as_Home_Team'] = pd.to_numeric(dataset['Win_Pct_as_Home_Team'])
    dataset['Win_Pct_as_Visitor_Team'] = pd.to_numeric(dataset['Win_Pct_as_Visitor_Team'])
    
    # Calculate Elo rating for each team based on win percentages
    dataset['Elo_Home'] = dataset['Win_Pct_as_Home_Team'].map(calculate_elo_rating)
    dataset['Elo_away'] = dataset['Win_Pct_as_Visitor_Team'].map(calculate_elo_rating)
    
    return dataset

# Assuming you have a dataset named 'games_df' with columns 'home_team', 'visitor_team', 'HOME_TEAM_WINS',
# 'Win_Pct_as_Home_Team', 'Win_Pct_as_Visitor_Team', 'Win_Pct'

# Add Elo ratings to the games_df dataframe
games_df = add_elo_ratings(games_df, 'home_team', 'visitor_team')

csv_filename = 'games_cleaned.csv'

# Save the updated dataframe to the CSV file
games_df.to_csv(csv_filename, index=False)

# Print the updated dataframe
games_df.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  home_team visitor_team  SEASON
# 0    2022-12-22  22200477            Final   Pelicans        Spurs    2022  \
# 1    2022-12-22  22200478            Final       Jazz      Wizards    2022
# 2    2022-12-21  22200466            Final  Cavaliers        Bucks    2022
# 3    2022-12-21  22200467            Final      76ers      Pistons    2022
# 4    2022-12-21  22200468            Final      Hawks        Bulls    2022
#
#    TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  FT_PCT_away
# 0    1610612740     126.0        0.484        0.926  ...        0.815  \
# 1    1610612762     120.0        0.488        0.952  ...        0.765
# 2    1610612739     114.0        0.482        0.786  ...        0.682
# 3    1610612755     113.0        0.441        0.909  ...        0.735
# 4    1610612737     108.0        0.429        1.000  ...        0.773
#
#    FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS  Win_Pct_as_Home_Team
# 0         0.321      23.0      44.0               1              3.197499  \
# 1         0.333      20.0      37.0               1              3.276589
# 2         0.433      20.0      46.0               1              3.461133
# 3         0.261      15.0      46.0               1              3.295420
# 4         0.292      20.0      47.0               0              3.318017
#
#    Win_Pct_as_Visitor_Team   Win_Pct     Elo_Home     Elo_away
# 0                 3.495029  3.495029  1586.319976  1595.840916
# 1                 3.359446  3.359446  1588.850859  1591.502260
# 2                 3.351913  3.351913  1594.756252  1591.261223
# 3                 3.329316  3.329316  1589.453450  1590.538114
# 4                 3.269057  3.269057  1590.176559  1588.609822
#
# [5 rows x 26 columns]

# %%
# finale dataset :

# deleting points and wins culmns . after using it to calculate the features X

games_df = pd.read_csv('games_cleaned.csv')

columns_to_drop = ['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'SEASON', 'PTS_home', 'PTS_away']
games_df = games_df.drop(columns=columns_to_drop)

games_df.head()
# Out:
#    home_team visitor_team  TEAM_ID_home  FG_PCT_home  FT_PCT_home
# 0   Pelicans        Spurs    1610612740        0.484        0.926  \
# 1       Jazz      Wizards    1610612762        0.488        0.952
# 2  Cavaliers        Bucks    1610612739        0.482        0.786
# 3      76ers      Pistons    1610612755        0.441        0.909
# 4      Hawks        Bulls    1610612737        0.429        1.000
#
#    FG3_PCT_home  AST_home  REB_home  TEAM_ID_away  FG_PCT_away  FT_PCT_away
# 0         0.382      25.0      46.0    1610612759        0.478        0.815  \
# 1         0.457      16.0      40.0    1610612764        0.561        0.765
# 2         0.313      22.0      37.0    1610612749        0.470        0.682
# 3         0.297      27.0      49.0    1610612765        0.392        0.735
# 4         0.378      22.0      47.0    1610612741        0.500        0.773
#
#    FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS  Win_Pct_as_Home_Team
# 0         0.321      23.0      44.0               1              3.197499  \
# 1         0.333      20.0      37.0               1              3.276589
# 2         0.433      20.0      46.0               1              3.461133
# 3         0.261      15.0      46.0               1              3.295420
# 4         0.292      20.0      47.0               0              3.318017
#
#    Win_Pct_as_Visitor_Team   Win_Pct     Elo_Home     Elo_away
# 0                 3.495029  3.495029  1586.319976  1595.840916
# 1                 3.359446  3.359446  1588.850859  1591.502260
# 2                 3.351913  3.351913  1594.756252  1591.261223
# 3                 3.329316  3.329316  1589.453450  1590.538114
# 4                 3.269057  3.269057  1590.176559  1588.609822

# %% [markdown]
# ### 2.2 Top Teams

# %%
home_wins = games_df[games_df['HOME_TEAM_WINS'] == 1]['home_team'].value_counts()
away_wins = games_df[games_df['HOME_TEAM_WINS'] == 0]['visitor_team'].value_counts()
teams_with_wins = list(set(home_wins.index) | set(away_wins.index))


home_wins = home_wins.loc[teams_with_wins]
away_wins = away_wins.loc[teams_with_wins]
fig, ax = plt.subplots(figsize=(10, 8))
bar_width = 0.35

r1 = np.arange(len(home_wins))
r2 = [x + bar_width for x in r1]

ax.bar(r1, home_wins, width=bar_width, label='Home Team Wins', color='blue')
ax.bar(r2, away_wins, width=bar_width, label='Away Team Wins', color='orange')

ax.set_xticks(r1 + bar_width / 2)
ax.set_xticklabels(teams_with_wins)

ax.set_title('Comparison of Wins: Home Team vs Away Team')
ax.set_xlabel('Team')
ax.set_ylabel('Number of Wins')

ax.legend()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
home_filt = games_df[games_df['HOME_TEAM_WINS'] == 1]
away_filt = games_df[games_df['HOME_TEAM_WINS'] == 0]
x = [
    home_filt['FG_PCT_home'].mean(),
    home_filt['FG3_PCT_home'].mean(),
    home_filt['FT_PCT_home'].mean()
]
y = [
    away_filt['FG_PCT_away'].mean(),
    away_filt['FG3_PCT_away'].mean(),
    away_filt['FT_PCT_away'].mean()
]
ti = ['Field Goal Percentage', 'Three Point Percentage', 'Free Throw Percentage']
plt.figure(figsize=(10, 6))
hor = np.arange(len(ti))

plt.bar(hor, x, width=0.25, color='#0077b6', label='Home Win Games')
plt.bar(hor + 0.25, y, width=0.25, color='#fb8500', label='Away Lose Games')
plt.xticks(hor + 0.125, ti)
plt.title('Comparison of Shooting Percentages: Home Win vs Away Lose Games')
plt.xlabel('Shooting Metric')
plt.ylabel('Mean Percentage')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Spliting

# %%
X = games_df.drop('HOME_TEAM_WINS', axis=1)  # Assuming 'HOME_TEAM_WINS' is the target variable
y = games_df['HOME_TEAM_WINS']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (18586, 19) (18586,)
# Testing set shape: (7966, 19) (7966,)

# %% [markdown]
# ## Classifiers and Evaluating the model's performance :

# %%
# IMPORTS
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB


from sklearn.metrics import precision_score, accuracy_score, recall_score, confusion_matrix

# %% [markdown]
# ## RandomForestClassifier

# %%
# features = ['TEAM_ID_home', 'TEAM_ID_away','FG_PCT_away','FT_PCT_away','FG3_PCT_away','AST_away','REB_away','Win_Pct_as_Home_Team','Win_Pct_as_Visitor_Team','Win_Pct']

# X_train = games_df[features]
# y_train = games_df['HOME_TEAM_WINS']

features = ['TEAM_ID_home', 'TEAM_ID_away','FG_PCT_away','FT_PCT_away','FG_PCT_home', 'FT_PCT_home','Elo_Home','Elo_away','Win_Pct_as_Home_Team','Win_Pct_as_Visitor_Team','Win_Pct']

X_train = games_df[features]
y_train = games_df['HOME_TEAM_WINS']



classifier = RandomForestClassifier()
classifier.fit(X_train, y_train)

y_train_pred = classifier.predict(X_train)


# Calculate precision
precision = precision_score(y_train, y_train_pred)
# print("Precision:", precision)

# Calculate accuracy
accuracy = accuracy_score(y_train, y_train_pred)
# print("Accuracy:", accuracy)

# Calculate recall
recall = recall_score(y_train, y_train_pred)
# print("Recall:", recall)

# Calculate true positive rate (TPR)
confusion_mat = confusion_matrix(y_train, y_train_pred)
tp = confusion_mat[1, 1]
fn = confusion_mat[1, 0]
tn = confusion_mat[0, 0]
fp = confusion_mat[0, 1]
tpr = tp / (tp + fn)
# print("True Positive Rate (TPR):", tpr)

# Calculate true negative rate (TNR)
tnr = tn / (tn + fp)
# print("True Negative Rate (TNR):", tnr)

# Create a dataframe to store the results
result_df = pd.DataFrame({'Metrics': ['Precision', 'Accuracy', 'Recall', 'True Positive Rate (TPR)', 'True Negative Rate (TNR)'],
                          'Random Forest Classifier': [precision, accuracy, recall, tpr, tnr]})
result_df.head()
# Out:
#                     Metrics  Random Forest Classifier
# 0                 Precision                  1.000000
# 1                  Accuracy                  0.999962
# 2                    Recall                  0.999936
# 3  True Positive Rate (TPR)                  0.999936
# 4  True Negative Rate (TNR)                  1.000000

# %% [markdown]
# ## SVM

# %%
# using same xtrain and ytrain 
# X_train = games_df[features]
# y_train = games_df['HOME_TEAM_WINS']
features = ['TEAM_ID_home', 'TEAM_ID_away','FG_PCT_away','FT_PCT_away','FG_PCT_home', 'FT_PCT_home','Elo_Home','Elo_away','Win_Pct_as_Home_Team','Win_Pct_as_Visitor_Team','Win_Pct']

X_train = games_df[features]
y_train = games_df['HOME_TEAM_WINS']





classifier = SVC()
classifier.fit(X_train, y_train)

y_train_pred = classifier.predict(X_train)



# Calculate precision
precision = precision_score(y_train, y_train_pred)
print("Precision:", precision)

# Calculate accuracy
accuracy = accuracy_score(y_train, y_train_pred)
print("Accuracy:", accuracy)

# Calculate recall
recall = recall_score(y_train, y_train_pred)
print("Recall:", recall)

# Calculate true positive rate (TPR)
confusion_mat = confusion_matrix(y_train, y_train_pred)
tp = confusion_mat[1, 1]
fn = confusion_mat[1, 0]
tn = confusion_mat[0, 0]
fp = confusion_mat[0, 1]
tpr = tp / (tp + fn)
print("True Positive Rate (TPR):", tpr)

# Calculate true negative rate (TNR)
tnr = tn / (tn + fp)
print("True Negative Rate (TNR):", tnr)


result_df['Support Vector Machine'] = [precision, accuracy, recall, tpr, tnr]
result_df.head()
# Out:
# Precision: 0.589221150949081
# Accuracy: 0.589221150949081
# Recall: 1.0
# True Positive Rate (TPR): 1.0
# True Negative Rate (TNR): 0.0
#                     Metrics  Random Forest Classifier  Support Vector Machine
# 0                 Precision                  1.000000                0.589221
# 1                  Accuracy                  0.999962                0.589221
# 2                    Recall                  0.999936                1.000000
# 3  True Positive Rate (TPR)                  0.999936                1.000000
# 4  True Negative Rate (TNR)                  1.000000                0.000000

# %% [markdown]
# ## the Logistic Regression classifier

# %%
features = ['TEAM_ID_home', 'TEAM_ID_away','FG_PCT_away','FT_PCT_away','FG_PCT_home', 'FT_PCT_home','Elo_Home','Elo_away','Win_Pct_as_Home_Team','Win_Pct_as_Visitor_Team','Win_Pct']

X_train = games_df[features]
y_train = games_df['HOME_TEAM_WINS']



classifier = LogisticRegression()
classifier.fit(X_train, y_train)

y_train_pred = classifier.predict(X_train)

# Calculate precision
precision = precision_score(y_train, y_train_pred)
print("Precision:", precision)

# Calculate accuracy
accuracy = accuracy_score(y_train, y_train_pred)
print("Accuracy:", accuracy)

# Calculate recall
recall = recall_score(y_train, y_train_pred)
print("Recall:", recall)

# Calculate true positive rate (TPR)
confusion_mat = confusion_matrix(y_train, y_train_pred)
tp = confusion_mat[1, 1]
fn = confusion_mat[1, 0]
tn = confusion_mat[0, 0]
fp = confusion_mat[0, 1]
tpr = tp / (tp + fn)
print("True Positive Rate (TPR):", tpr)

# Calculate true negative rate (TNR)
tnr = tn / (tn + fp)
print("True Negative Rate (TNR):", tnr)

result_df['Logistic Regression classifie'] = [precision, accuracy, recall, tpr, tnr]
result_df.head()
# Out:
# Precision: 0.589221150949081
# Accuracy: 0.589221150949081
# Recall: 1.0
# True Positive Rate (TPR): 1.0
# True Negative Rate (TNR): 0.0
#                     Metrics  Random Forest Classifier  Support Vector Machine
# 0                 Precision                  1.000000                0.589221  \
# 1                  Accuracy                  0.999962                0.589221
# 2                    Recall                  0.999936                1.000000
# 3  True Positive Rate (TPR)                  0.999936                1.000000
# 4  True Negative Rate (TNR)                  1.000000                0.000000
#
#    Logistic Regression classifie
# 0                       0.589221
# 1                       0.589221
# 2                       1.000000
# 3                       1.000000
# 4                       0.000000

# %% [markdown]
# ## KNeighbors Classifier

# %%
features = ['TEAM_ID_home', 'TEAM_ID_away','FG_PCT_away','FT_PCT_away','FG_PCT_home', 'FT_PCT_home','Elo_Home','Elo_away','Win_Pct_as_Home_Team','Win_Pct_as_Visitor_Team','Win_Pct']

X_train = games_df[features]
y_train = games_df['HOME_TEAM_WINS']



classifier = KNeighborsClassifier(n_neighbors=5)

classifier.fit(X_train, y_train)
y_train_pred = classifier.predict(X_train)

# Evaluate the model's accuracy on the training data
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy)


# Calculate recall
recall = recall_score(y_train, y_train_pred)
print("Recall:", recall)

# Calculate true positive rate (TPR)
confusion_mat = confusion_matrix(y_train, y_train_pred)
tp = confusion_mat[1, 1]
fn = confusion_mat[1, 0]
tn = confusion_mat[0, 0]
fp = confusion_mat[0, 1]
tpr = tp / (tp + fn)
print("True Positive Rate (TPR):", tpr)

# Calculate true negative rate (TNR)
tnr = tn / (tn + fp)
print("True Negative Rate (TNR):", tnr)


result_df['KNeighbors Classifier'] = [precision, accuracy, recall, tpr, tnr]
result_df.head()
# Out:
# Training Accuracy: 0.8033669780054233
# Recall: 0.8697347395333973
# True Positive Rate (TPR): 0.8697347395333973
# True Negative Rate (TNR): 0.7081690657375997
#                     Metrics  Random Forest Classifier  Support Vector Machine
# 0                 Precision                  1.000000                0.589221  \
# 1                  Accuracy                  0.999962                0.589221
# 2                    Recall                  0.999936                1.000000
# 3  True Positive Rate (TPR)                  0.999936                1.000000
# 4  True Negative Rate (TNR)                  1.000000                0.000000
#
#    Logistic Regression classifie  KNeighbors Classifier
# 0                       0.589221               0.589221
# 1                       0.589221               0.589221
# 2                       1.000000               0.869735
# 3                       1.000000               0.869735
# 4                       0.000000               0.708169

# %% [markdown]
# ## Naive Bayes

# %%
features = ['TEAM_ID_home', 'TEAM_ID_away','FG_PCT_away','FT_PCT_away','FG_PCT_home', 'FT_PCT_home','Elo_Home','Elo_away','Win_Pct_as_Home_Team','Win_Pct_as_Visitor_Team','Win_Pct']

X_train = games_df[features]
y_train = games_df['HOME_TEAM_WINS']



classifier = GaussianNB()
classifier.fit(X_train, y_train)
y_train_pred = classifier.predict(X_train)


# Evaluate the model's accuracy on the training data
train_accuracy = accuracy_score(y_train, y_train_pred)
print("Training Accuracy:", train_accuracy)


# Calculate recall
recall = recall_score(y_train, y_train_pred)
print("Recall:", recall)

# Calculate true positive rate (TPR)
confusion_mat = confusion_matrix(y_train, y_train_pred)
tp = confusion_mat[1, 1]
fn = confusion_mat[1, 0]
tn = confusion_mat[0, 0]
fp = confusion_mat[0, 1]
tpr = tp / (tp + fn)
print("True Positive Rate (TPR):", tpr)

# Calculate true negative rate (TNR)
tnr = tn / (tn + fp)
print("True Negative Rate (TNR):", tnr)


result_df['Naive Bayes'] = [precision, accuracy, recall, tpr, tnr]
result_df.head()
# Out:
# Training Accuracy: 0.5890705031636035
# Recall: 0.8315755832534356
# True Positive Rate (TPR): 0.8315755832534356
# True Negative Rate (TNR): 0.2412212340698634
#                     Metrics  Random Forest Classifier  Support Vector Machine
# 0                 Precision                       1.0                0.589221  \
# 1                  Accuracy                       1.0                0.589221
# 2                    Recall                       1.0                1.000000
# 3  True Positive Rate (TPR)                       1.0                1.000000
# 4  True Negative Rate (TNR)                       1.0                0.000000
#
#    Logistic Regression classifie  KNeighbors Classifier  Naive Bayes
# 0                       0.589221               0.589221     0.589221
# 1                       0.589221               0.589221     0.589221
# 2                       1.000000               0.656632     0.831576
# 3                       1.000000               0.656632     0.831576
# 4                       0.000000               0.433025     0.241221
